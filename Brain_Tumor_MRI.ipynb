# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Instalar dependências
# !pip install kagglehub
# !pip install tensorflow
# !pip install matplotlib

# Montar o Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Configurar o diretório de destino
import os
import kagglehub
import shutil

dest_dir = '/content/drive/MyDrive/PAI5'
os.makedirs(dest_dir, exist_ok=True)

# Fazer o download do dataset
bilalakgz_brain_tumor_mri_dataset_path = kagglehub.dataset_download('bilalakgz/brain-tumor-mri-dataset')

# Mover arquivos do dataset para a pasta de destino
for item in os.listdir(bilalakgz_brain_tumor_mri_dataset_path):
    shutil.move(os.path.join(bilalakgz_brain_tumor_mri_dataset_path, item), dest_dir)

print(f"Arquivos movidos para: {dest_dir}")

print("Arquivos na pasta 'PAI5':")
print(os.listdir(dest_dir))
# Out:
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.10/dist-packages (0.3.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from kagglehub) (24.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kagglehub) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kagglehub) (4.66.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub) (2024.8.30)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.68.0)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy<2,>=1.21 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Arquivos movidos para: /content/drive/MyDrive/PAI5
# Arquivos na pasta 'PAI4':
# ['brain_tumor_dataset']

# %% [markdown]
# # Configuração dos caminhos do dataset

# %%
import os
# Configuração dos caminhos do dataset
folder_path = '/content/drive/MyDrive/PAI/brain_tumor_dataset'
train_dir = os.path.join(folder_path, 'brain_tumor_segmentation/train/images')
val_dir = os.path.join(folder_path, 'brain_tumor_segmentation/valid/images')
test_dir = os.path.join(folder_path, 'brain_tumor_segmentation/test')

# Verificar se os caminhos estão corretos
print("Caminho para treino:", train_dir)
print("Caminho para validação:", val_dir)
print("Caminho para teste:", test_dir)
# Out:
# Caminho para treino: /content/drive/MyDrive/PAI/brain_tumor_dataset/brain_tumor_segmentation/train/images
# Caminho para validação: /content/drive/MyDrive/PAI/brain_tumor_dataset/brain_tumor_segmentation/valid/images
# Caminho para teste: /content/drive/MyDrive/PAI/brain_tumor_dataset/brain_tumor_segmentation/test

# %% [markdown]
# #Treinamento

# %%
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2
from tensorflow.keras import layers, Model

# Configurar os caminhos das pastas
folder_path = '/content/drive/MyDrive/PAI/brain_tumor_dataset/brain_tumor_segmentation'
train_images_dir = os.path.join(folder_path, 'train/images')
train_labels_dir = os.path.join(folder_path, 'train/labels')
test_images_dir = os.path.join(folder_path, 'test/images')
test_labels_dir = os.path.join(folder_path, 'test/labels')
val_images_dir = os.path.join(folder_path, 'valid/images')
val_labels_dir = os.path.join(folder_path, 'valid/labels')

# Função para carregar e preprocessar os dados com arquivos .txt para máscaras
import cv2  # Certifique-se de importar o OpenCV

def load_data_with_txt(image_dir, label_dir, img_height, img_width):
    images, labels = [], []
    for image_file in sorted(os.listdir(image_dir)):
        # Carregar e redimensionar imagens
        image_path = os.path.join(image_dir, image_file)
        label_path = os.path.join(label_dir, image_file.replace('.jpg', '.txt'))  # Assumindo que máscaras são .txt

        # Carregar e normalizar a imagem
        image = tf.keras.preprocessing.image.load_img(image_path, target_size=(img_height, img_width))
        image = tf.keras.preprocessing.image.img_to_array(image) / 255.0
        images.append(image)

        # Criar a máscara a partir das coordenadas do .txt
        label = np.zeros((img_height, img_width, 1), dtype=np.float32)
        with open(label_path, 'r') as file:
            for line in file:
                values = list(map(float, line.strip().split()))
                class_id, *points = values
                # Converter pontos para coordenadas da máscara
                polygon = np.array(points).reshape(-1, 2) * [img_width, img_height]
                cv2.fillPoly(label, [polygon.astype(np.int32)], 1)

        labels.append(label)

    return np.array(images), np.array(labels)


# Configurações
IMG_HEIGHT, IMG_WIDTH = 128, 128
BATCH_SIZE = 1  # Aumente o batch size conforme a capacidade da GPU

# Carregar os dados
train_images, train_labels = load_data_with_txt(train_images_dir, train_labels_dir, IMG_HEIGHT, IMG_WIDTH)
val_images, val_labels = load_data_with_txt(val_images_dir, val_labels_dir, IMG_HEIGHT, IMG_WIDTH)

# Criar um dataset tf.data com paralelismo
def preprocess_dataset(images, labels):
    dataset = tf.data.Dataset.from_tensor_slices((images, labels))
    dataset = dataset.map(lambda x, y: (tf.image.resize(x, [IMG_HEIGHT, IMG_WIDTH]), y), num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.shuffle(100).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

    # Adicionando visualização para debug
    for img, lbl in dataset.take(1):  # Visualizar o primeiro lote
        plt.figure(figsize=(10, 5))
        for i in range(min(5, BATCH_SIZE)):  # Exibir até 5 imagens do lote
            plt.subplot(2, 5, i+1)
            plt.imshow((img[i].numpy() * 255).astype("uint8"))
            plt.title("Imagem")
            plt.axis('off')

            plt.subplot(2, 5, i+6)
            plt.imshow(lbl[i].numpy().astype("uint8"), cmap='gray')
            plt.title("Máscara")
            plt.axis('off')

            # Debug: imprimir valores únicos da imagem
            print(f"Valores únicos da imagem: {np.unique(img[i].numpy())}")

        plt.tight_layout()
        plt.show()

    return dataset

train_dataset = preprocess_dataset(train_images, train_labels)
val_dataset = preprocess_dataset(val_images, val_labels)

# Substituir a dependência do pix2pix
def upsample(filters, size):
    """Camada de transposição de convolução para upsampling."""
    return tf.keras.Sequential([
        layers.Conv2DTranspose(filters, size, strides=2, padding='same'),
        layers.BatchNormalization(),
        layers.ReLU()
    ])

# Construir o modelo usando DeepLabV3+
base_model = tf.keras.applications.MobileNetV2(input_shape=[IMG_HEIGHT, IMG_WIDTH, 3], include_top=False)
base_model.trainable = False

# Camadas específicas para a segmentação
layer_names = [
    'block_1_expand_relu',   # Baixa resolução
    'block_3_expand_relu',   # Média resolução
    'block_6_expand_relu',   # Alta resolução
    'block_13_expand_relu',  # Maior resolução
    'block_16_project',      # Final
]
base_model_outputs = [base_model.get_layer(name).output for name in layer_names]

down_stack = Model(inputs=base_model.input, outputs=base_model_outputs)
down_stack.trainable = False

up_stack = [
    upsample(512, 3),  # 512 filtros
    upsample(256, 3),  # 256 filtros
    upsample(128, 3),  # 128 filtros
    upsample(64, 3),   # 64 filtros
]

# Função para construir o modelo
def unet_model(output_channels):
    inputs = layers.Input(shape=[IMG_HEIGHT, IMG_WIDTH, 3])

    # Encoder
    skips = down_stack(inputs)
    x = skips[-1]
    skips = reversed(skips[:-1])

    # Decoder
    for up, skip in zip(up_stack, skips):
        x = up(x)
        x = layers.Concatenate()([x, skip])

    # Saída
    x = layers.Conv2DTranspose(output_channels, 3, strides=2, padding='same')(x)
    return Model(inputs=inputs, outputs=x)

OUTPUT_CLASSES = 1  # Binário: tumor ou não
#define_model = unet_model(OUTPUT_CLASSES)
#define_model.compile(optimizer='adam', loss=tf.keras.losses.BinaryCrossentropy(from_logits=True), metrics=['accuracy'])

def unet_model_with_dropout(output_channels):
    inputs = layers.Input(shape=[IMG_HEIGHT, IMG_WIDTH, 3])

    skips = down_stack(inputs)
    x = skips[-1]
    skips = reversed(skips[:-1])

    for up, skip in zip(up_stack, skips):
        x = up(x)
        x = layers.Concatenate()([x, skip])
        x = layers.Dropout(0.5)(x)  # Adicionando dropout

    x = layers.Conv2DTranspose(output_channels, 3, strides=2, padding='same')(x)
    return Model(inputs=inputs, outputs=x)

define_model = unet_model_with_dropout(OUTPUT_CLASSES)
define_model.compile(optimizer='adam', loss=tf.keras.losses.BinaryCrossentropy(from_logits=True), metrics=['accuracy'])


define_model.summary()

# Treinar o modelo
EPOCHS = 100
history = define_model.fit(train_dataset, validation_data=val_dataset, epochs=EPOCHS)

# Avaliar o modelo
loss, accuracy = define_model.evaluate(val_dataset)
print(f"Loss: {loss}, Accuracy: {accuracy}")

# Função para criar a máscara a partir da predição
def create_mask(pred_mask):
    # Aplicar a função sigmoid para converter logits em probabilidades entre 0 e 1
    pred_mask = tf.sigmoid(pred_mask)

    # Binarizar a máscara usando um limiar de 0.5 e atribuir -1 ao invés de 0
    pred_mask = tf.where(pred_mask > 0.5, 1, -1)

    # Retornar a primeira máscara da batch
    return pred_mask[0]

# Plotar as métricas de perda e acurácia
def plot_training_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(len(acc))

    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Treinamento')
    plt.plot(epochs_range, val_acc, label='Validação')
    plt.legend(loc='lower right')
    plt.title('Acurácia')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Treinamento')
    plt.plot(epochs_range, val_loss, label='Validação')
    plt.legend(loc='upper right')
    plt.title('Perda')

    plt.show()

plot_training_history(history)
# Out:
# Valores únicos da imagem: [0.         0.00392157 0.00784314 0.01176471 0.01568628 0.01960784
#  0.02352941 0.02745098 0.03137255 0.03529412 0.03921569 0.04313726
#  0.04705882 0.05098039 0.05490196 0.05882353 0.0627451  0.06666667
#  0.07058824 0.07450981 0.07843138 0.08235294 0.08627451 0.09019608
#  0.09411765 0.09803922 0.10196079 0.10588235 0.10980392 0.11372549
#  0.11764706 0.12156863 0.1254902  0.12941177 0.13333334 0.13725491
#  0.14117648 0.14509805 0.14901961 0.15294118 0.15686275 0.16078432
#  0.16470589 0.16862746 0.17254902 0.1764706  0.18039216 0.18431373
#  0.1882353  0.19215687 0.19607843 0.2        0.20392157 0.20784314
#  0.21176471 0.21568628 0.21960784 0.22352941 0.22745098 0.23137255
#  0.23529412 0.23921569 0.24313726 0.24705882 0.2509804  0.25490198
#  0.25882354 0.2627451  0.26666668 0.27058825 0.27450982 0.2784314
#  0.28235295 0.28627452 0.2901961  0.29411766 0.29803923 0.3019608
#  0.30588236 0.30980393 0.3137255  0.31764707 0.32156864 0.3254902
#  0.32941177 0.33333334 0.3372549  0.34117648 0.34509805 0.34901962
#  0.3529412  0.35686275 0.36078432 0.3647059  0.36862746 0.37254903
#  0.3764706  0.38039216 0.38431373 0.3882353  0.39215687 0.39607844
#  0.4        0.40392157 0.40784314 0.4117647  0.41568628 0.41960785
#  0.42352942 0.42745098 0.43137255 0.43529412 0.4392157  0.44313726
#  0.44705883 0.4509804  0.45490196 0.45882353 0.4627451  0.46666667
#  0.47058824 0.4745098  0.47843137 0.48235294 0.4862745  0.49019608
#  0.49411765 0.49803922 0.5019608  0.5058824  0.50980395 0.5137255
#  0.5176471  0.52156866 0.5254902  0.5294118  0.53333336 0.5372549
#  0.5411765  0.54509807 0.54901963 0.5529412  0.5568628  0.56078434
#  0.5647059  0.5686275  0.57254905 0.5764706  0.5803922  0.58431375
#  0.5882353  0.5921569  0.59607846 0.6        0.6039216  0.60784316
#  0.6117647  0.61960787 0.62352943 0.627451   0.6313726  0.63529414
#  0.6392157  0.6431373  0.64705884 0.6509804  0.65882355 0.6745098
#  0.6901961  0.69411767 0.69803923 0.70980394 0.7176471  0.72156864
#  0.7254902  0.7294118  0.74509805 0.7490196  0.75686276 0.77254903
#  0.7764706  0.78039217 0.7882353  0.8039216  0.80784315 0.827451
#  0.85490197 0.8745098  0.8784314  0.8901961  0.89411765 0.94509804
#  0.96862745]
# Valores únicos da imagem: [0.         0.00392157 0.00784314 0.01176471 0.01568628 0.01960784
#  0.02352941 0.02745098 0.03137255 0.03529412 0.03921569 0.04313726
#  0.04705882 0.05098039 0.05490196 0.05882353 0.0627451  0.06666667
#  0.07058824 0.07450981 0.07843138 0.08235294 0.08627451 0.09019608
#  0.09411765 0.09803922 0.10196079 0.10588235 0.10980392 0.11372549
#  0.11764706 0.12156863 0.1254902  0.12941177 0.13333334 0.13725491
#  0.14117648 0.14509805 0.14901961 0.15294118 0.15686275 0.16078432
#  0.16470589 0.16862746 0.17254902 0.1764706  0.18039216 0.18431373
#  0.1882353  0.19215687 0.19607843 0.2        0.20392157 0.20784314
#  0.21176471 0.21568628 0.21960784 0.22352941 0.22745098 0.23137255
#  0.23529412 0.23921569 0.24313726 0.24705882 0.2509804  0.25490198
#  0.25882354 0.2627451  0.26666668 0.27058825 0.27450982 0.2784314
#  0.28235295 0.28627452 0.2901961  0.29411766 0.29803923 0.3019608
#  0.30588236 0.30980393 0.3137255  0.31764707 0.32156864 0.3254902
#  0.32941177 0.33333334 0.3372549  0.34117648 0.34509805 0.34901962
#  0.3529412  0.35686275 0.36078432 0.3647059  0.36862746 0.37254903
#  0.3764706  0.38039216 0.38431373 0.3882353  0.39215687 0.39607844
#  0.4        0.40392157 0.40784314 0.4117647  0.41568628 0.41960785
#  0.42352942 0.42745098 0.43137255 0.43529412 0.4392157  0.44313726
#  0.44705883 0.4509804  0.45490196 0.45882353 0.4627451  0.46666667
#  0.47058824 0.4745098  0.47843137 0.48235294 0.4862745  0.49019608
#  0.49411765 0.49803922 0.5019608  0.5058824  0.50980395 0.5137255
#  0.5176471  0.52156866 0.5254902  0.5294118  0.53333336 0.5372549
#  0.5411765  0.54509807 0.54901963 0.5529412  0.5568628  0.56078434
#  0.5647059  0.5686275  0.57254905 0.5764706  0.5803922  0.58431375
#  0.5882353  0.5921569  0.59607846 0.6        0.6039216  0.60784316
#  0.6117647  0.6156863  0.61960787 0.62352943 0.627451   0.6313726
#  0.63529414 0.6392157  0.6431373  0.64705884 0.6509804  0.654902
#  0.65882355 0.6627451  0.6666667  0.67058825 0.6745098  0.6784314
#  0.68235296 0.6862745  0.6901961  0.69411767 0.69803923 0.7019608
#  0.7058824  0.70980394 0.7137255  0.7176471  0.72156864 0.7254902
#  0.7294118  0.73333335 0.7372549  0.7411765  0.74509805 0.7490196
#  0.7529412  0.75686276 0.7607843  0.7647059  0.76862746 0.77254903
#  0.7764706  0.78039217 0.78431374 0.7882353  0.7921569  0.79607844
#  0.8        0.8039216  0.80784315 0.8117647  0.8156863  0.81960785
#  0.8235294  0.827451   0.83137256 0.8352941  0.8392157  0.84313726
#  0.84705883 0.8509804  0.85490197 0.85882354 0.8627451  0.8666667
#  0.87058824 0.8745098  0.8784314  0.88235295 0.8862745  0.8901961
#  0.89411765 0.8980392  0.9019608  0.90588236 0.9098039  0.9137255
#  0.91764706 0.92156863 0.9254902  0.92941177 0.93333334 0.9372549
#  0.9411765  0.94509804 0.9490196  0.9529412  0.95686275 0.9607843
#  0.9647059  0.96862745 0.972549   0.9764706  0.98039216 0.9843137
#  0.9882353  0.99215686 0.99607843 1.        ]
# Model: "functional_244"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_96            │ (None, 128, 128, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ functional_239            │ [(None, 64, 64, 96),   │      1,841,984 │ input_layer_96[0][0]   │
# │ (Functional)              │ (None, 32, 32, 144),   │                │                        │
# │                           │ (None, 16, 16, 192),   │                │                        │
# │                           │ (None, 8, 8, 576),     │                │                        │
# │                           │ (None, 4, 4, 320)]     │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ sequential_66             │ (None, 8, 8, 512)      │      1,477,120 │ functional_239[0][4]   │
# │ (Sequential)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_64            │ (None, 8, 8, 1088)     │              0 │ sequential_66[0][0],   │
# │ (Concatenate)             │                        │                │ functional_239[0][3]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_28 (Dropout)      │ (None, 8, 8, 1088)     │              0 │ concatenate_64[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ sequential_67             │ (None, 16, 16, 256)    │      2,508,032 │ dropout_28[0][0]       │
# │ (Sequential)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_65            │ (None, 16, 16, 448)    │              0 │ sequential_67[0][0],   │
# │ (Concatenate)             │                        │                │ functional_239[0][2]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_29 (Dropout)      │ (None, 16, 16, 448)    │              0 │ concatenate_65[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ sequential_68             │ (None, 32, 32, 128)    │        516,736 │ dropout_29[0][0]       │
# │ (Sequential)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_66            │ (None, 32, 32, 272)    │              0 │ sequential_68[0][0],   │
# │ (Concatenate)             │                        │                │ functional_239[0][1]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_30 (Dropout)      │ (None, 32, 32, 272)    │              0 │ concatenate_66[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ sequential_69             │ (None, 64, 64, 64)     │        156,992 │ dropout_30[0][0]       │
# │ (Sequential)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_67            │ (None, 64, 64, 160)    │              0 │ sequential_69[0][0],   │
# │ (Concatenate)             │                        │                │ functional_239[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_31 (Dropout)      │ (None, 64, 64, 160)    │              0 │ concatenate_67[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_69       │ (None, 128, 128, 1)    │          1,441 │ dropout_31[0][0]       │
# │ (Conv2DTranspose)         │                        │                │                        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 6,502,305 (24.80 MB)
#  Trainable params: 4,658,401 (17.77 MB)
#  Non-trainable params: 1,843,904 (7.03 MB)
# Epoch 1/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 16s 35ms/step - accuracy: 0.8792 - loss: 0.3669 - val_accuracy: 0.9713 - val_loss: 0.1134
# Epoch 2/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9717 - loss: 0.1102 - val_accuracy: 0.9720 - val_loss: 0.1162
# Epoch 3/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9776 - loss: 0.0744 - val_accuracy: 0.9760 - val_loss: 0.0708
# Epoch 4/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9783 - loss: 0.0672 - val_accuracy: 0.9808 - val_loss: 0.0492
# Epoch 5/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9809 - loss: 0.0576 - val_accuracy: 0.9783 - val_loss: 0.0561
# Epoch 6/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9795 - loss: 0.0581 - val_accuracy: 0.9805 - val_loss: 0.0469
# Epoch 7/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9805 - loss: 0.0527 - val_accuracy: 0.9810 - val_loss: 0.0456
# Epoch 8/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9828 - loss: 0.0464 - val_accuracy: 0.9813 - val_loss: 0.0451
# Epoch 9/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9822 - loss: 0.0465 - val_accuracy: 0.9811 - val_loss: 0.0459
# Epoch 10/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9818 - loss: 0.0459 - val_accuracy: 0.9788 - val_loss: 0.0554
# Epoch 11/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9851 - loss: 0.0382 - val_accuracy: 0.9798 - val_loss: 0.0518
# Epoch 12/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9852 - loss: 0.0371 - val_accuracy: 0.9786 - val_loss: 0.0638
# Epoch 13/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9858 - loss: 0.0373 - val_accuracy: 0.9830 - val_loss: 0.0449
# Epoch 14/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9860 - loss: 0.0349 - val_accuracy: 0.9823 - val_loss: 0.0452
# Epoch 15/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9888 - loss: 0.0297 - val_accuracy: 0.9828 - val_loss: 0.0463
# Epoch 16/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9882 - loss: 0.0306 - val_accuracy: 0.9821 - val_loss: 0.0488
# Epoch 17/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9886 - loss: 0.0298 - val_accuracy: 0.9830 - val_loss: 0.0416
# Epoch 18/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9859 - loss: 0.0348 - val_accuracy: 0.9834 - val_loss: 0.0444
# Epoch 19/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9886 - loss: 0.0285 - val_accuracy: 0.9847 - val_loss: 0.0390
# Epoch 20/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9881 - loss: 0.0303 - val_accuracy: 0.9846 - val_loss: 0.0409
# Epoch 21/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9885 - loss: 0.0296 - val_accuracy: 0.9812 - val_loss: 0.0545
# Epoch 22/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9903 - loss: 0.0246 - val_accuracy: 0.9843 - val_loss: 0.0443
# Epoch 23/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9880 - loss: 0.0306 - val_accuracy: 0.9838 - val_loss: 0.0462
# Epoch 24/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9911 - loss: 0.0227 - val_accuracy: 0.9818 - val_loss: 0.0577
# Epoch 25/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9910 - loss: 0.0237 - val_accuracy: 0.9809 - val_loss: 0.0614
# Epoch 26/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9903 - loss: 0.0243 - val_accuracy: 0.9813 - val_loss: 0.0646
# Epoch 27/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9911 - loss: 0.0223 - val_accuracy: 0.9823 - val_loss: 0.0553
# Epoch 28/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9912 - loss: 0.0230 - val_accuracy: 0.9835 - val_loss: 0.0503
# Epoch 29/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9924 - loss: 0.0197 - val_accuracy: 0.9819 - val_loss: 0.0552
# Epoch 30/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9923 - loss: 0.0202 - val_accuracy: 0.9835 - val_loss: 0.0514
# Epoch 31/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9909 - loss: 0.0231 - val_accuracy: 0.9825 - val_loss: 0.0549
# Epoch 32/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9913 - loss: 0.0214 - val_accuracy: 0.9833 - val_loss: 0.0585
# Epoch 33/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9926 - loss: 0.0185 - val_accuracy: 0.9840 - val_loss: 0.0498
# Epoch 34/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9932 - loss: 0.0174 - val_accuracy: 0.9843 - val_loss: 0.0542
# Epoch 35/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9932 - loss: 0.0173 - val_accuracy: 0.9843 - val_loss: 0.0531
# Epoch 36/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9929 - loss: 0.0184 - val_accuracy: 0.9825 - val_loss: 0.0615
# Epoch 37/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9928 - loss: 0.0178 - val_accuracy: 0.9815 - val_loss: 0.0684
# Epoch 38/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9939 - loss: 0.0155 - val_accuracy: 0.9861 - val_loss: 0.0450
# Epoch 39/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9939 - loss: 0.0158 - val_accuracy: 0.9839 - val_loss: 0.0500
# Epoch 40/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9937 - loss: 0.0155 - val_accuracy: 0.9821 - val_loss: 0.0643
# Epoch 41/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9938 - loss: 0.0152 - val_accuracy: 0.9849 - val_loss: 0.0513
# Epoch 42/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9936 - loss: 0.0159 - val_accuracy: 0.9839 - val_loss: 0.0566
# Epoch 43/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9935 - loss: 0.0160 - val_accuracy: 0.9849 - val_loss: 0.0534
# Epoch 44/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9942 - loss: 0.0144 - val_accuracy: 0.9830 - val_loss: 0.0618
# Epoch 45/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9940 - loss: 0.0144 - val_accuracy: 0.9837 - val_loss: 0.0650
# Epoch 46/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9947 - loss: 0.0139 - val_accuracy: 0.9840 - val_loss: 0.0583
# Epoch 47/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9943 - loss: 0.0143 - val_accuracy: 0.9819 - val_loss: 0.0734
# Epoch 48/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9944 - loss: 0.0143 - val_accuracy: 0.9813 - val_loss: 0.0762
# Epoch 49/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9933 - loss: 0.0160 - val_accuracy: 0.9840 - val_loss: 0.0583
# Epoch 50/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9950 - loss: 0.0125 - val_accuracy: 0.9824 - val_loss: 0.0713
# Epoch 51/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9943 - loss: 0.0140 - val_accuracy: 0.9820 - val_loss: 0.0770
# Epoch 52/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9945 - loss: 0.0137 - val_accuracy: 0.9832 - val_loss: 0.0725
# Epoch 53/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9948 - loss: 0.0132 - val_accuracy: 0.9821 - val_loss: 0.0804
# Epoch 54/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9951 - loss: 0.0122 - val_accuracy: 0.9815 - val_loss: 0.0824
# Epoch 55/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9943 - loss: 0.0142 - val_accuracy: 0.9834 - val_loss: 0.0654
# Epoch 56/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9952 - loss: 0.0120 - val_accuracy: 0.9847 - val_loss: 0.0595
# Epoch 57/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9951 - loss: 0.0126 - val_accuracy: 0.9841 - val_loss: 0.0660
# Epoch 58/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9957 - loss: 0.0111 - val_accuracy: 0.9851 - val_loss: 0.0593
# Epoch 59/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9951 - loss: 0.0123 - val_accuracy: 0.9848 - val_loss: 0.0661
# Epoch 60/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9950 - loss: 0.0128 - val_accuracy: 0.9852 - val_loss: 0.0623
# Epoch 61/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9950 - loss: 0.0125 - val_accuracy: 0.9829 - val_loss: 0.0802
# Epoch 62/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9951 - loss: 0.0117 - val_accuracy: 0.9819 - val_loss: 0.0869
# Epoch 63/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9951 - loss: 0.0122 - val_accuracy: 0.9834 - val_loss: 0.0737
# Epoch 64/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9957 - loss: 0.0113 - val_accuracy: 0.9828 - val_loss: 0.0757
# Epoch 65/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9947 - loss: 0.0134 - val_accuracy: 0.9828 - val_loss: 0.0781
# Epoch 66/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9953 - loss: 0.0114 - val_accuracy: 0.9821 - val_loss: 0.0793
# Epoch 67/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9954 - loss: 0.0112 - val_accuracy: 0.9839 - val_loss: 0.0761
# Epoch 68/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9952 - loss: 0.0122 - val_accuracy: 0.9837 - val_loss: 0.0706
# Epoch 69/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9952 - loss: 0.0125 - val_accuracy: 0.9845 - val_loss: 0.0652
# Epoch 70/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9954 - loss: 0.0116 - val_accuracy: 0.9843 - val_loss: 0.0668
# Epoch 71/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9952 - loss: 0.0122 - val_accuracy: 0.9832 - val_loss: 0.0772
# Epoch 72/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9953 - loss: 0.0121 - val_accuracy: 0.9812 - val_loss: 0.0932
# Epoch 73/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9958 - loss: 0.0105 - val_accuracy: 0.9831 - val_loss: 0.0814
# Epoch 74/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9960 - loss: 0.0102 - val_accuracy: 0.9846 - val_loss: 0.0685
# Epoch 75/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9959 - loss: 0.0102 - val_accuracy: 0.9849 - val_loss: 0.0683
# Epoch 76/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9956 - loss: 0.0110 - val_accuracy: 0.9839 - val_loss: 0.0759
# Epoch 77/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9955 - loss: 0.0113 - val_accuracy: 0.9821 - val_loss: 0.0912
# Epoch 78/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9958 - loss: 0.0100 - val_accuracy: 0.9842 - val_loss: 0.0747
# Epoch 79/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9960 - loss: 0.0105 - val_accuracy: 0.9832 - val_loss: 0.0833
# Epoch 80/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9961 - loss: 0.0096 - val_accuracy: 0.9826 - val_loss: 0.0885
# Epoch 81/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9953 - loss: 0.0116 - val_accuracy: 0.9842 - val_loss: 0.0742
# Epoch 82/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9959 - loss: 0.0109 - val_accuracy: 0.9827 - val_loss: 0.0919
# Epoch 83/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9959 - loss: 0.0102 - val_accuracy: 0.9853 - val_loss: 0.0620
# Epoch 84/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9963 - loss: 0.0096 - val_accuracy: 0.9843 - val_loss: 0.0757
# Epoch 85/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9960 - loss: 0.0100 - val_accuracy: 0.9843 - val_loss: 0.0724
# Epoch 86/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9956 - loss: 0.0112 - val_accuracy: 0.9843 - val_loss: 0.0726
# Epoch 87/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9959 - loss: 0.0100 - val_accuracy: 0.9849 - val_loss: 0.0639
# Epoch 88/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9964 - loss: 0.0091 - val_accuracy: 0.9839 - val_loss: 0.0779
# Epoch 89/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9960 - loss: 0.0097 - val_accuracy: 0.9837 - val_loss: 0.0830
# Epoch 90/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9957 - loss: 0.0107 - val_accuracy: 0.9821 - val_loss: 0.1036
# Epoch 91/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9956 - loss: 0.0108 - val_accuracy: 0.9846 - val_loss: 0.0764
# Epoch 92/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9965 - loss: 0.0089 - val_accuracy: 0.9851 - val_loss: 0.0712
# Epoch 93/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9967 - loss: 0.0083 - val_accuracy: 0.9843 - val_loss: 0.0796
# Epoch 94/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9966 - loss: 0.0086 - val_accuracy: 0.9845 - val_loss: 0.0743
# Epoch 95/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9964 - loss: 0.0092 - val_accuracy: 0.9854 - val_loss: 0.0696
# Epoch 96/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9964 - loss: 0.0092 - val_accuracy: 0.9834 - val_loss: 0.0865
# Epoch 97/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9963 - loss: 0.0091 - val_accuracy: 0.9828 - val_loss: 0.0972
# Epoch 98/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9962 - loss: 0.0094 - val_accuracy: 0.9836 - val_loss: 0.0881
# Epoch 99/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9964 - loss: 0.0088 - val_accuracy: 0.9844 - val_loss: 0.0733
# Epoch 100/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9966 - loss: 0.0085 - val_accuracy: 0.9837 - val_loss: 0.0820
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9803 - loss: 0.1107
# Loss: 0.08199942111968994, Accuracy: 0.9837198853492737

# %%
# Variável para definir quantos resultados serão exibidos
num_results = 10  # Você pode escolher o número desejado, como 5, 10, etc.

# Função para exibir múltiplos exemplos de imagens de entrada, máscaras verdadeiras e máscaras preditas
def display_multiple_results(dataset, model, num_results=5):
    plt.figure(figsize=(15, num_results * 5))  # Ajustar o tamanho da figura para mais resultados
    title = ["Imagem de Origem", "Máscara Real", "Máscara Predita"]

    # Iterar sobre os exemplos desejados
    for i, (image, mask) in enumerate(dataset.take(num_results)):
        pred_mask = model.predict(image)  # Fazer a predição

        for j, img in enumerate([image[0], mask[0], create_mask(pred_mask)]):
            plt.subplot(num_results, 3, i * 3 + j + 1)
            plt.title(title[j])
            plt.imshow(tf.keras.utils.array_to_img(img))
            plt.axis('off')

    plt.tight_layout()
    plt.show()

# Exibir os resultados
display_multiple_results(val_dataset, define_model, num_results=num_results)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step

# %% [markdown]
# # SALVAR E UTILIZAR O MODELO GERADO

# %%
import tensorflow as tf

# Assumindo que você já treinou o modelo e o atribuiu à variável 'define_model'
model = define_model  # Substitua pelo nome real do seu modelo treinado

# Salvar o modelo no formato Keras nativo
model_save_path = '/content/drive/MyDrive/PAI/meu_modelo_treinado.keras'
model.save(model_save_path)

print(f"Modelo salvo com sucesso em: {model_save_path}")
# Out:
# Modelo salvo com sucesso em: /content/drive/MyDrive/PAI/meu_modelo_treinado.keras

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import regularizers

# Caminho do modelo salvo
model_save_path = '/content/drive/MyDrive/PAI/meu_modelo_treinado.keras'

# Compilar o modelo
model.compile(optimizer='adam', loss=tf.keras.losses.BinaryCrossentropy(from_logits=True), metrics=['accuracy'])

print(f"Modelo carregado com sucesso de: {model_save_path}")

# Função para exibir os resultados qualitativos
def display_sample_results(images, labels, predictions, num_samples=5):
    plt.figure(figsize=(15, num_samples * 5))
    for i in range(num_samples):
        plt.subplot(num_samples, 3, i * 3 + 1)
        plt.title("Imagem Original")
        plt.imshow(images[i].squeeze(), cmap='gray' if images[i].shape[-1] == 1 else None)

        plt.subplot(num_samples, 3, i * 3 + 2)
        plt.title("Máscara Real")
        plt.imshow(labels[i].squeeze(), cmap='gray')

        plt.subplot(num_samples, 3, i * 3 + 3)
        plt.title("Máscara Predita")
        plt.imshow(predictions[i].squeeze(), cmap='gray')

        # Adicionar a linha vermelha na área predita
        plt.contour(predictions[i].squeeze(), levels=[0.5], colors='red')

    plt.tight_layout()
    plt.show()


# Carregar os dados de teste
import cv2

def display_sample_results(images, labels, predictions, num_samples=5, target_height=256, target_width=256):
    plt.figure(figsize=(15, num_samples * 5))
    for i in range(num_samples):
        plt.subplot(num_samples, 3, i * 3 + 1)
        plt.title("Imagem Original")
        plt.imshow(images[i].squeeze(), cmap='gray' if images[i].shape[-1] == 1 else None)

        plt.subplot(num_samples, 3, i * 3 + 2)
        plt.title("Máscara Real")
        plt.imshow(labels[i].squeeze(), cmap='gray')

        plt.subplot(num_samples, 3, i * 3 + 3)
        plt.title("Máscara Predita")

        # Redimensionar a máscara predita para o tamanho original
        prediction_resized = cv2.resize(predictions[i].squeeze(), (target_width, target_height), interpolation=cv2.INTER_LINEAR)
        plt.imshow(prediction_resized, cmap='gray')

        # Adicionar a linha vermelha na área predita redimensionada
        plt.contour(prediction_resized, levels=[0.5], colors='red')

    plt.tight_layout()
    plt.show()


IMG_HEIGHT, IMG_WIDTH = 256, 256  # Dimensões originais
TARGET_HEIGHT, TARGET_WIDTH = 128, 128  # Dimensões que o modelo espera

# Carregar e redimensionar os dados de teste
test_images, test_labels = load_data_with_txt(test_images_dir, test_labels_dir, IMG_HEIGHT, IMG_WIDTH, TARGET_HEIGHT, TARGET_WIDTH)

# Pré-processar os dados de teste (sem embaralhar)
test_dataset = tf.data.Dataset.from_tensor_slices((test_images, test_labels))
test_dataset = test_dataset.batch(1).prefetch(tf.data.AUTOTUNE)

# Avaliação no conjunto de teste
test_loss, test_accuracy = model.evaluate(test_dataset)
print(f"Teste - Loss: {test_loss}, Accuracy: {test_accuracy}")

# Fazer predições no conjunto de teste
predictions = model.predict(test_dataset)

# Certifique-se de que os arrays são NumPy
test_images_numpy = np.array(test_images)
test_labels_numpy = np.array(test_labels)
predictions_numpy = np.array(predictions)

# Exibir os primeiros 5 exemplos de teste
display_sample_results(test_images_numpy[:5], test_labels_numpy[:5], predictions_numpy[:5])
# Out:
# Modelo carregado com sucesso de: /content/drive/MyDrive/PAI/meu_modelo_treinado.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9973 - loss: 0.0052
# Teste - Loss: 0.004843538627028465, Accuracy: 0.9977661371231079
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step

# %%
history = model.fit(test_dataset, validation_data=val_dataset, epochs=EPOCHS)

# Salvar o histórico de treinamento
history_dict = history.history
# Out:
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 13s 25ms/step - accuracy: 0.9845 - loss: 0.0971 - val_accuracy: 0.9785 - val_loss: 0.1492
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9882 - loss: 0.0340 - val_accuracy: 0.9762 - val_loss: 0.1894
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9890 - loss: 0.0277 - val_accuracy: 0.9761 - val_loss: 0.1873
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9897 - loss: 0.0274 - val_accuracy: 0.9761 - val_loss: 0.1872
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9904 - loss: 0.0234 - val_accuracy: 0.9767 - val_loss: 0.1668
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9918 - loss: 0.0219 - val_accuracy: 0.9777 - val_loss: 0.1431
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9916 - loss: 0.0195 - val_accuracy: 0.9778 - val_loss: 0.1354
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9916 - loss: 0.0193 - val_accuracy: 0.9784 - val_loss: 0.1299
# Epoch 9/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9927 - loss: 0.0178 - val_accuracy: 0.9794 - val_loss: 0.1231
# Epoch 10/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9943 - loss: 0.0140 - val_accuracy: 0.9788 - val_loss: 0.1318
# Epoch 11/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9930 - loss: 0.0151 - val_accuracy: 0.9811 - val_loss: 0.1085
# Epoch 12/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9945 - loss: 0.0132 - val_accuracy: 0.9798 - val_loss: 0.1203
# Epoch 13/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9941 - loss: 0.0153 - val_accuracy: 0.9819 - val_loss: 0.0992
# Epoch 14/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9943 - loss: 0.0139 - val_accuracy: 0.9809 - val_loss: 0.1125
# Epoch 15/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9944 - loss: 0.0125 - val_accuracy: 0.9807 - val_loss: 0.1101
# Epoch 16/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9941 - loss: 0.0146 - val_accuracy: 0.9812 - val_loss: 0.1088
# Epoch 17/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9953 - loss: 0.0114 - val_accuracy: 0.9803 - val_loss: 0.1202
# Epoch 18/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9953 - loss: 0.0110 - val_accuracy: 0.9825 - val_loss: 0.0969
# Epoch 19/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9949 - loss: 0.0123 - val_accuracy: 0.9816 - val_loss: 0.1049
# Epoch 20/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9962 - loss: 0.0090 - val_accuracy: 0.9816 - val_loss: 0.1079
# Epoch 21/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9958 - loss: 0.0106 - val_accuracy: 0.9818 - val_loss: 0.1089
# Epoch 22/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9957 - loss: 0.0106 - val_accuracy: 0.9817 - val_loss: 0.1099
# Epoch 23/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9956 - loss: 0.0097 - val_accuracy: 0.9825 - val_loss: 0.1012
# Epoch 24/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9961 - loss: 0.0104 - val_accuracy: 0.9822 - val_loss: 0.1035
# Epoch 25/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9966 - loss: 0.0077 - val_accuracy: 0.9818 - val_loss: 0.1120
# Epoch 26/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9961 - loss: 0.0098 - val_accuracy: 0.9817 - val_loss: 0.1123
# Epoch 27/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9968 - loss: 0.0084 - val_accuracy: 0.9817 - val_loss: 0.1131
# Epoch 28/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9939 - loss: 0.0172 - val_accuracy: 0.9819 - val_loss: 0.1162
# Epoch 29/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9958 - loss: 0.0103 - val_accuracy: 0.9808 - val_loss: 0.1290
# Epoch 30/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9963 - loss: 0.0095 - val_accuracy: 0.9813 - val_loss: 0.1165
# Epoch 31/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9960 - loss: 0.0089 - val_accuracy: 0.9822 - val_loss: 0.1065
# Epoch 32/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9951 - loss: 0.0126 - val_accuracy: 0.9806 - val_loss: 0.1244
# Epoch 33/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9964 - loss: 0.0088 - val_accuracy: 0.9820 - val_loss: 0.1103
# Epoch 34/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9967 - loss: 0.0087 - val_accuracy: 0.9807 - val_loss: 0.1204
# Epoch 35/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9963 - loss: 0.0087 - val_accuracy: 0.9814 - val_loss: 0.1168
# Epoch 36/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9965 - loss: 0.0086 - val_accuracy: 0.9822 - val_loss: 0.1051
# Epoch 37/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9964 - loss: 0.0091 - val_accuracy: 0.9821 - val_loss: 0.1066
# Epoch 38/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9971 - loss: 0.0073 - val_accuracy: 0.9817 - val_loss: 0.1124
# Epoch 39/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9964 - loss: 0.0086 - val_accuracy: 0.9817 - val_loss: 0.1112
# Epoch 40/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9971 - loss: 0.0075 - val_accuracy: 0.9811 - val_loss: 0.1208
# Epoch 41/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9970 - loss: 0.0072 - val_accuracy: 0.9816 - val_loss: 0.1151
# Epoch 42/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9970 - loss: 0.0073 - val_accuracy: 0.9817 - val_loss: 0.1098
# Epoch 43/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9967 - loss: 0.0081 - val_accuracy: 0.9820 - val_loss: 0.1117
# Epoch 44/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9970 - loss: 0.0075 - val_accuracy: 0.9812 - val_loss: 0.1244
# Epoch 45/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9973 - loss: 0.0070 - val_accuracy: 0.9816 - val_loss: 0.1211
# Epoch 46/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9972 - loss: 0.0068 - val_accuracy: 0.9826 - val_loss: 0.1106
# Epoch 47/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9971 - loss: 0.0078 - val_accuracy: 0.9811 - val_loss: 0.1266
# Epoch 48/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9976 - loss: 0.0061 - val_accuracy: 0.9815 - val_loss: 0.1225
# Epoch 49/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9973 - loss: 0.0063 - val_accuracy: 0.9813 - val_loss: 0.1248
# Epoch 50/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9970 - loss: 0.0077 - val_accuracy: 0.9816 - val_loss: 0.1207
# Epoch 51/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9974 - loss: 0.0061 - val_accuracy: 0.9809 - val_loss: 0.1314
# Epoch 52/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9972 - loss: 0.0070 - val_accuracy: 0.9816 - val_loss: 0.1216
# Epoch 53/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9974 - loss: 0.0058 - val_accuracy: 0.9822 - val_loss: 0.1093
# Epoch 54/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9974 - loss: 0.0065 - val_accuracy: 0.9817 - val_loss: 0.1173
# Epoch 55/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9967 - loss: 0.0072 - val_accuracy: 0.9812 - val_loss: 0.1275
# Epoch 56/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9977 - loss: 0.0068 - val_accuracy: 0.9820 - val_loss: 0.1166
# Epoch 57/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9975 - loss: 0.0061 - val_accuracy: 0.9825 - val_loss: 0.1096
# Epoch 58/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9975 - loss: 0.0062 - val_accuracy: 0.9812 - val_loss: 0.1289
# Epoch 59/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9975 - loss: 0.0061 - val_accuracy: 0.9807 - val_loss: 0.1353
# Epoch 60/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9977 - loss: 0.0056 - val_accuracy: 0.9805 - val_loss: 0.1477
# Epoch 61/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9979 - loss: 0.0052 - val_accuracy: 0.9805 - val_loss: 0.1432
# Epoch 62/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9980 - loss: 0.0053 - val_accuracy: 0.9800 - val_loss: 0.1440
# Epoch 63/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9973 - loss: 0.0065 - val_accuracy: 0.9809 - val_loss: 0.1316
# Epoch 64/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9977 - loss: 0.0053 - val_accuracy: 0.9808 - val_loss: 0.1353
# Epoch 65/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9974 - loss: 0.0065 - val_accuracy: 0.9799 - val_loss: 0.1459
# Epoch 66/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9976 - loss: 0.0060 - val_accuracy: 0.9799 - val_loss: 0.1432
# Epoch 67/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9978 - loss: 0.0058 - val_accuracy: 0.9804 - val_loss: 0.1359
# Epoch 68/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9977 - loss: 0.0060 - val_accuracy: 0.9801 - val_loss: 0.1435
# Epoch 69/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9977 - loss: 0.0059 - val_accuracy: 0.9798 - val_loss: 0.1497
# Epoch 70/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9976 - loss: 0.0055 - val_accuracy: 0.9795 - val_loss: 0.1538
# Epoch 71/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9973 - loss: 0.0075 - val_accuracy: 0.9795 - val_loss: 0.1527
# Epoch 72/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9974 - loss: 0.0062 - val_accuracy: 0.9803 - val_loss: 0.1412
# Epoch 73/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9977 - loss: 0.0057 - val_accuracy: 0.9797 - val_loss: 0.1447
# Epoch 74/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9975 - loss: 0.0059 - val_accuracy: 0.9802 - val_loss: 0.1390
# Epoch 75/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9981 - loss: 0.0046 - val_accuracy: 0.9800 - val_loss: 0.1419
# Epoch 76/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9980 - loss: 0.0049 - val_accuracy: 0.9804 - val_loss: 0.1381
# Epoch 77/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9978 - loss: 0.0051 - val_accuracy: 0.9805 - val_loss: 0.1365
# Epoch 78/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9977 - loss: 0.0055 - val_accuracy: 0.9795 - val_loss: 0.1509
# Epoch 79/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9978 - loss: 0.0056 - val_accuracy: 0.9805 - val_loss: 0.1393
# Epoch 80/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9977 - loss: 0.0062 - val_accuracy: 0.9805 - val_loss: 0.1432
# Epoch 81/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9975 - loss: 0.0069 - val_accuracy: 0.9808 - val_loss: 0.1339
# Epoch 82/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9981 - loss: 0.0047 - val_accuracy: 0.9807 - val_loss: 0.1340
# Epoch 83/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9981 - loss: 0.0049 - val_accuracy: 0.9814 - val_loss: 0.1289
# Epoch 84/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9981 - loss: 0.0051 - val_accuracy: 0.9806 - val_loss: 0.1376
# Epoch 85/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9981 - loss: 0.0043 - val_accuracy: 0.9809 - val_loss: 0.1371
# Epoch 86/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9975 - loss: 0.0063 - val_accuracy: 0.9813 - val_loss: 0.1287
# Epoch 87/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9983 - loss: 0.0045 - val_accuracy: 0.9808 - val_loss: 0.1363
# Epoch 88/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9977 - loss: 0.0053 - val_accuracy: 0.9814 - val_loss: 0.1314
# Epoch 89/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9979 - loss: 0.0052 - val_accuracy: 0.9788 - val_loss: 0.1660
# Epoch 90/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9976 - loss: 0.0060 - val_accuracy: 0.9801 - val_loss: 0.1445
# Epoch 91/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9981 - loss: 0.0045 - val_accuracy: 0.9801 - val_loss: 0.1423
# Epoch 92/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9978 - loss: 0.0051 - val_accuracy: 0.9795 - val_loss: 0.1510
# Epoch 93/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9982 - loss: 0.0049 - val_accuracy: 0.9804 - val_loss: 0.1430
# Epoch 94/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9981 - loss: 0.0052 - val_accuracy: 0.9796 - val_loss: 0.1507
# Epoch 95/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9982 - loss: 0.0043 - val_accuracy: 0.9799 - val_loss: 0.1501
# Epoch 96/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9982 - loss: 0.0045 - val_accuracy: 0.9799 - val_loss: 0.1545
# Epoch 97/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9982 - loss: 0.0044 - val_accuracy: 0.9793 - val_loss: 0.1645
# Epoch 98/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9981 - loss: 0.0045 - val_accuracy: 0.9808 - val_loss: 0.1455
# Epoch 99/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9980 - loss: 0.0055 - val_accuracy: 0.9805 - val_loss: 0.1432
# Epoch 100/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9982 - loss: 0.0048 - val_accuracy: 0.9801 - val_loss: 0.1492

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    # Plotar Perda
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(history['loss'], label='Perda de Treinamento')
    plt.plot(history['val_loss'], label='Perda de Validação')
    plt.xlabel('Época')
    plt.ylabel('Perda')
    plt.legend()
    plt.title('Perda de Treinamento e Validação')

    # Plotar Precisão
    plt.subplot(1, 2, 2)
    plt.plot(history['accuracy'], label='Precisão de Treinamento')
    plt.plot(history['val_accuracy'], label='Precisão de Validação')
    plt.xlabel('Época')
    plt.ylabel('Precisão')
    plt.legend()
    plt.title('Precisão de Treinamento e Validação')

    plt.tight_layout()
    plt.show()

# Chamar a função de plotagem
plot_training_history(history_dict)

# %%
# Resultados no conjunto de teste
test_loss, test_accuracy = model.evaluate(test_dataset)
print(f"Teste - Loss: {test_loss}, Accuracy: {test_accuracy}")
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9973 - loss: 0.0052
# Teste - Loss: 0.004843538627028465, Accuracy: 0.9977661371231079
